# %% [markdown]
# # Circuit preprocessor: Misano circuit

# %%
import sys,os,inspect
fastest_lap_top_level=os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))))
sys.path.append(fastest_lap_top_level + '/examples/python')
import fastest_lap
import fastest_lap_utils

# %%
options = "<options>"
options += "    <kml_files>"
options += "        <left>../../../database/tracks/misano/misano_left.kml</left>"
options += "        <right>../../../database/tracks/misano/misano_right.kml</right>"
options += "    </kml_files>"
options += "    <mode>equally-spaced</mode>"
options += "    <is_closed>true</is_closed>" 
options += "    <number_of_elements>1000</number_of_elements>" # for tracks that doesn't work just put casual numbers under 1000
options += "    <xml_file_name>github.xml</xml_file_name>"
options += "    <output_variables>"
options += "        <prefix>track/</prefix>"
options += "    </output_variables>"
options += "</options>"

fastest_lap.circuit_preprocessor(options)

# %%
fastest_lap_utils.plot_turn(220, 690, "Turn 1-2-3");
#fastest_lap_utils.plot_turn(110, 170, "Turn 2");
#fastest_lap_utils.plot_turn(100, 120, "Turn 3");
fastest_lap_utils.plot_turn(800, 970, "Turn 4-5");
#fastest_lap_utils.plot_turn(290, 330, "Turn 5");
fastest_lap_utils.plot_turn(990, 1100, "Turn 6");
fastest_lap_utils.plot_turn(1640, 1860, "Turn 7");
fastest_lap_utils.plot_turn(2150, 2300, "Turn 8");
fastest_lap_utils.plot_turn(2800, 2890, "Turn 9");
fastest_lap_utils.plot_turn(3060, 3170, "Turn 10");
fastest_lap_utils.plot_turn(3230, 3320, "Turn 11");
fastest_lap_utils.plot_turn(3380, 3520, "Turn 12");
fastest_lap_utils.plot_turn(3600, 3730, "Turn 13");
fastest_lap_utils.plot_turn(3870, 3980, "Turn 14");
"""fastest_lap_utils.plot_turn(4400, 4800, "Turn 16");"""

# %%
fastest_lap_utils.plot_turn(2820, 2910, "Turn 9");
fastest_lap_utils.plot_turn(3090, 3210, "Turn 10");
fastest_lap_utils.plot_turn(3270, 3360, "Turn 11");
fastest_lap_utils.plot_turn(3420, 3580, "Turn 12");
fastest_lap_utils.plot_turn(3640, 3740, "Turn 13");
fastest_lap_utils.plot_turn(3920, 4020, "Turn 14");
