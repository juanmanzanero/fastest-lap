# %% [markdown]
# # Circuit preprocessor: Misano karting circuit

# %%
import sys,os,inspect
fastest_lap_top_level=os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))))
sys.path.append(fastest_lap_top_level + '/examples/python')
import fastest_lap
import fastest_lap_utils

# %%
options = "<options>"
options += "    <kml_files>"
options += "        <left>../../../database/tracks/misano/misanino_left.kml</left>"
options += "        <right>../../../database/tracks/misano/misanino_right.kml</right>"
options += "    </kml_files>"
options += "    <mode>equally-spaced</mode>"
options += "    <is_closed>true</is_closed>" 
options += "    <number_of_elements>1000</number_of_elements>" # for tracks that doesn't work just put casual numbers under 1000
options += "    <xml_file_name>github.xml</xml_file_name>"
options += "    <output_variables>"
options += "        <prefix>track/</prefix>"
options += "    </output_variables>"
options += "</options>"

fastest_lap.circuit_preprocessor(options)

# %%
fastest_lap_utils.plot_turn(70, 105, "Turn 1");
fastest_lap_utils.plot_turn(110, 170, "Turn 2-3");
#fastest_lap_utils.plot_turn(100, 120, "Turn 3");
fastest_lap_utils.plot_turn(250, 285, "Turn 4");
fastest_lap_utils.plot_turn(290, 330, "Turn 5");
fastest_lap_utils.plot_turn(330, 395, "Turn 6");
fastest_lap_utils.plot_turn(420, 570, "Turn 7-8-9");
#fastest_lap_utils.plot_turn(330, 395, "Turns 8");
#fastest_lap_utils.plot_turn(370, 400, "Turn 9");
fastest_lap_utils.plot_turn(660, 770, "Turn 10");
fastest_lap_utils.plot_turn(770, 800, "Turn 11");
"""fastest_lap_utils.plot_turn(770, 800, "Turn 12");
fastest_lap_utils.plot_turn(1160, 1220, "Turn 13");
fastest_lap_utils.plot_turn(3400, 3800, "Turn 14-15");
fastest_lap_utils.plot_turn(4400, 4800, "Turn 16");"""
# Out:
# 'fastest_lap_utils.plot_turn(770, 800, "Turn 12");\nfastest_lap_utils.plot_turn(1160, 1220, "Turn 13");\nfastest_lap_utils.plot_turn(3400, 3800, "Turns 14-15");\nfastest_lap_utils.plot_turn(4400, 4800, "Turn 16");'
