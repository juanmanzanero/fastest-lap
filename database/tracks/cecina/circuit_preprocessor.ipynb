# %% [markdown]
# # Circuit preprocessor: Cecina circuit

# %%
import sys,os,inspect
fastest_lap_top_level=os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))))
sys.path.append(fastest_lap_top_level + '/examples/python')
import fastest_lap
import fastest_lap_utils

# %%
options = "<options>"
options += "    <kml_files>"
options += "        <left>../../../database/tracks/cecina/cecina_left.kml</left>"
options += "        <right>../../../database/tracks/cecina/cecina_right.kml</right>"
options += "    </kml_files>"
options += "    <mode>equally-spaced</mode>"
options += "    <is_closed>true</is_closed>" 
options += "    <number_of_elements>1000</number_of_elements>" # for tracks that doesn't work just put casual numbers under 1000
options += "    <xml_file_name>github.xml</xml_file_name>"
options += "    <output_variables>"
options += "        <prefix>track/</prefix>"
options += "    </output_variables>"
options += "</options>"

fastest_lap.circuit_preprocessor(options)

# %%
fastest_lap_utils.plot_turn(30, 80, "Turn 1");
fastest_lap_utils.plot_turn(115, 150, "Turn 2");
fastest_lap_utils.plot_turn(275, 320, "Turn 3");
fastest_lap_utils.plot_turn(435, 500, "Turn 4-5");
#fastest_lap_utils.plot_turn(420, 480, "Turn 5");
fastest_lap_utils.plot_turn(510, 550, "Turn 6");
fastest_lap_utils.plot_turn(620, 700, "Turns 7");
fastest_lap_utils.plot_turn(765, 800, "Turns 8");
fastest_lap_utils.plot_turn(880, 910, "Turn 9");
fastest_lap_utils.plot_turn(960, 990, "Turns 10");
fastest_lap_utils.plot_turn(1030, 1070, "Turns 11");
fastest_lap_utils.plot_turn(1100, 1160, "Turn 12");
#fastest_lap_utils.plot_turn(1160, 1220, "Turn 13");
"""fastest_lap_utils.plot_turn(3400, 3800, "Turns 14-15");
fastest_lap_utils.plot_turn(4400, 4800, "Turn 16");"""

# %%
fastest_lap_utils.plot_turn(290, 360, "Turn 3");
fastest_lap_utils.plot_turn(1050, 1090, "Turns 11");
