# %% [markdown]
# # Circuit preprocessor: Arezzo karting circuit

# %%
import sys,os,inspect
fastest_lap_top_level=os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))))
sys.path.append(fastest_lap_top_level + '/examples/python')
import fastest_lap
import fastest_lap_utils

# %%
options = "<options>"
options += "    <kml_files>"
options += "        <left>../../../database/tracks/arezzo/arezzo_left.kml</left>"
options += "        <right>../../../database/tracks/arezzo/arezzo_right.kml</right>"
options += "    </kml_files>"
options += "    <mode>equally-spaced</mode>"
options += "    <is_closed>true</is_closed>" 
options += "    <number_of_elements>1000</number_of_elements>" # for tracks that doesn't work just put casual numbers under 1000
options += "    <xml_file_name>github.xml</xml_file_name>"
options += "    <output_variables>"
options += "        <prefix>track/</prefix>"
options += "    </output_variables>"
options += "</options>"

fastest_lap.circuit_preprocessor(options)

# %%
fastest_lap_utils.plot_turn(40, 110, "Turn 1");
fastest_lap_utils.plot_turn(290, 335, "Turn 2");
fastest_lap_utils.plot_turn(388, 500, "Turn 3");
fastest_lap_utils.plot_turn(519, 560, "Turn 4");
fastest_lap_utils.plot_turn(575, 625, "Turn 5");
fastest_lap_utils.plot_turn(675, 770, "Turn 6");
"""fastest_lap_utils.plot_turn(210, 252, "Turns 7-8");
fastest_lap_utils.plot_turn(252, 294, "Turn 9");
fastest_lap_utils.plot_turn(294, 336, "Turns 10-11");
fastest_lap_utils.plot_turn(336, 380, "Turn 12");
fastest_lap_utils.plot_turn(380, 422, "Turn 13");
fastest_lap_utils.plot_turn(3400, 3800, "Turns 14-15");
fastest_lap_utils.plot_turn(4400, 4800, "Turn 16");"""
# Out:
# 'fastest_lap_utils.plot_turn(210, 252, "Turns 7-8");\nfastest_lap_utils.plot_turn(252, 294, "Turn 9");\nfastest_lap_utils.plot_turn(294, 336, "Turns 10-11");\nfastest_lap_utils.plot_turn(336, 380, "Turn 12");\nfastest_lap_utils.plot_turn(380, 422, "Turn 13");\nfastest_lap_utils.plot_turn(3400, 3800, "Turns 14-15");\nfastest_lap_utils.plot_turn(4400, 4800, "Turn 16");'
